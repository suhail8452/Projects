# %%
import numpy as np
import sys
import matplotlib.pyplot as plt
from scipy import signal
from astropy.io import fits
from sklearn.decomposition import FastICA, PCA
from scipy.stats import pearsonr as pear
from PIL import Image, ImageDraw
import matplotlib.image as mpimg

# %%
#load images
#image1 = mpimg.imread('images/Variance_noise100.png')
#image2 = mpimg.imread('images/Variance_noise1000.png')
#image3 = mpimg.imread('images/Variance_noise10000.png')

# %%
fig, axes = plt.subplots(3,1,figsize = (20,20))

#display images

#axes[0].imshow(image1)
#axes[0].set_title('100 hours observation')

#axes[1].imshow(image2)
#axes[1].set_title('1000 hours observation')

#axes[2].imshow(image3)
#axes[2].set_title('10000 hours observation')

for ax in axes:
    ax.axis('off')
    
plt.tight_layout()
#plt.savefig('images/observation_noise.png')
plt.close()

# %%
#load images of power spectrum 2D
image1 = mpimg.imread('images/Extra galactic emission.png')
image2 = mpimg.imread('images/Free-free emissions.png')
image3 = mpimg.imread('images/Synchrotron emission.png')
image4 = mpimg.imread('images/Thermal noise.png')
image5 = mpimg.imread('images/Cosmological signal.png')

# %%
fig, axes = plt.subplots(2,2,figsize = (6,5), constrained_layout=True)

#display images
axes[0,0].imshow(image3)
axes[0,0].axis('off')

axes[0,1].imshow(image1)
axes[0,1].axis('off')

axes[1,0].imshow(image2)
axes[1,0].axis('off')

axes[1,1].imshow(image4)
axes[1,1].axis('off')

#plt.tight_layout()
#frequency of 128.2MHz
plt.savefig('Submit/2Dpowerspectrum.png')
#plt.show()
#plt.close()

# %%
plt.figure()
plt.imshow(image5)
plt.axis('off')
plt.savefig('Submit/2D_cosmo.png')

# %% [markdown]
# ## power spectrum figures

# %%
#1d power spectrum images
#load images
image1 = mpimg.imread('images/powerspectrum for lightcone.png')
image2 = mpimg.imread('images/powerspectrum for foregrounds.png')
image3 = mpimg.imread('images/powerspectrum for noise.png')
image4 = mpimg.imread('images/powerspectrum for residual.png')

# %%
fig, axes = plt.subplots(2,2,figsize = (10,10))

#display images

axes[0,0].imshow(image1)
axes[0,0].axis('off')

axes[0,1].imshow(image2)
axes[0,1].axis('off')

axes[1,0].imshow(image3)
axes[1,0].axis('off')

axes[1,1].imshow(image4)
axes[1,1].axis('off')

    
plt.tight_layout()
#plt.savefig('images/power_spectrum_subplots.png')
#plt.show()
plt.close()

# %%
#load images of power spectrum 2D
image2 = mpimg.imread('images/ncomp/n = 1.png')
image3 = mpimg.imread('images/ncomp/n = 2.png')
image4 = mpimg.imread('images/ncomp/n = 3.png')
image5 = mpimg.imread('images/ncomp/n = 4.png')
image6 = mpimg.imread('images/ncomp/n = 5.png')
image7 = mpimg.imread('images/ncomp/n = 10.png')
image8 = mpimg.imread('images/ncomp/n = 20.png')
image9 = mpimg.imread('images/ncomp/Actual 21cmsignal.png')

# %%
#subplot of the images
images = [image2,image3,image4,image5,image6,image7,image8,image9]

# %%
fig, axes = plt.subplots(2,4, figsize=(14,8))

axes = axes.flatten()

for i, ax in enumerate(axes):
    ax.imshow(images[i])
    ax.axis('off')
plt.tight_layout()
#plt.show()

plt.savefig('Submit/powerspectrum2D.png')
# redo the images but fix the colorbar for all the images
