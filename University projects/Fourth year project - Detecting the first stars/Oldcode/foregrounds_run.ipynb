# %%
from foreground_sim import ForeGsim
import astropy.io.fits as fits
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
steps = 342
sim_test = ForeGsim(nfreq= steps,numin = 108, nustep = 0.3,ngrid = 128, imgsize=3.0) 
#342 slices

# %%
# %%time
syn_test = sim_test.gen_sync_map()  #synchotron emission, already meaned zero
hdu = fits.PrimaryHDU(syn_test)
hdul = fits.HDUList([hdu])
hdul.writeto('fits_files/syn_test.fits',overwrite=True)
# Out:
# Generating random field
# Generating random field
# ['SYN', '@108.0MHz:', 'DONE!']
# ['SYN', '@108.3MHz:', 'DONE!']
# ['SYN', '@108.6MHz:', 'DONE!']
# ['SYN', '@108.9MHz:', 'DONE!']
# ['SYN', '@109.2MHz:', 'DONE!']
# ['SYN', '@109.5MHz:', 'DONE!']
# ['SYN', '@109.8MHz:', 'DONE!']
# ['SYN', '@110.1MHz:', 'DONE!']
# ['SYN', '@110.4MHz:', 'DONE!']
# ['SYN', '@110.7MHz:', 'DONE!']
# ['SYN', '@111.0MHz:', 'DONE!']
# ['SYN', '@111.3MHz:', 'DONE!']
# ['SYN', '@111.6MHz:', 'DONE!']
# ['SYN', '@111.9MHz:', 'DONE!']
# ['SYN', '@112.2MHz:', 'DONE!']
# ['SYN', '@112.5MHz:', 'DONE!']
# ['SYN', '@112.8MHz:', 'DONE!']
# ['SYN', '@113.1MHz:', 'DONE!']
# ['SYN', '@113.4MHz:', 'DONE!']
# ['SYN', '@113.7MHz:', 'DONE!']
# ['SYN', '@114.0MHz:', 'DONE!']
# ['SYN', '@114.3MHz:', 'DONE!']
# ['SYN', '@114.6MHz:', 'DONE!']
# ['SYN', '@114.9MHz:', 'DONE!']
# ['SYN', '@115.2MHz:', 'DONE!']
# ['SYN', '@115.5MHz:', 'DONE!']
# ['SYN', '@115.8MHz:', 'DONE!']
# ['SYN', '@116.1MHz:', 'DONE!']
# ['SYN', '@116.4MHz:', 'DONE!']
# ['SYN', '@116.7MHz:', 'DONE!']
# ['SYN', '@117.0MHz:', 'DONE!']
# ['SYN', '@117.3MHz:', 'DONE!']
# ['SYN', '@117.6MHz:', 'DONE!']
# ['SYN', '@117.9MHz:', 'DONE!']
# ['SYN', '@118.2MHz:', 'DONE!']
# ['SYN', '@118.5MHz:', 'DONE!']
# ['SYN', '@118.8MHz:', 'DONE!']
# ['SYN', '@119.1MHz:', 'DONE!']
# ['SYN', '@119.4MHz:', 'DONE!']
# ['SYN', '@119.7MHz:', 'DONE!']
# ['SYN', '@120.0MHz:', 'DONE!']
# ['SYN', '@120.3MHz:', 'DONE!']
# ['SYN', '@120.6MHz:', 'DONE!']
# ['SYN', '@120.9MHz:', 'DONE!']
# ['SYN', '@121.2MHz:', 'DONE!']
# ['SYN', '@121.5MHz:', 'DONE!']
# ['SYN', '@121.8MHz:', 'DONE!']
# ['SYN', '@122.1MHz:', 'DONE!']
# ['SYN', '@122.4MHz:', 'DONE!']
# ['SYN', '@122.7MHz:', 'DONE!']
# ['SYN', '@123.0MHz:', 'DONE!']
# ['SYN', '@123.3MHz:', 'DONE!']
# ['SYN', '@123.6MHz:', 'DONE!']
# ['SYN', '@123.9MHz:', 'DONE!']
# ['SYN', '@124.2MHz:', 'DONE!']
# ['SYN', '@124.5MHz:', 'DONE!']
# ['SYN', '@124.8MHz:', 'DONE!']
# ['SYN', '@125.1MHz:', 'DONE!']
# ['SYN', '@125.4MHz:', 'DONE!']
# ['SYN', '@125.7MHz:', 'DONE!']
# ['SYN', '@126.0MHz:', 'DONE!']
# ['SYN', '@126.3MHz:', 'DONE!']
# ['SYN', '@126.6MHz:', 'DONE!']
# ['SYN', '@126.9MHz:', 'DONE!']
# ['SYN', '@127.2MHz:', 'DONE!']
# ['SYN', '@127.5MHz:', 'DONE!']
# ['SYN', '@127.8MHz:', 'DONE!']
# ['SYN', '@128.1MHz:', 'DONE!']
# ['SYN', '@128.4MHz:', 'DONE!']
# ['SYN', '@128.7MHz:', 'DONE!']
# ['SYN', '@129.0MHz:', 'DONE!']
# ['SYN', '@129.3MHz:', 'DONE!']
# ['SYN', '@129.6MHz:', 'DONE!']
# ['SYN', '@129.9MHz:', 'DONE!']
# ['SYN', '@130.2MHz:', 'DONE!']
# ['SYN', '@130.5MHz:', 'DONE!']
# ['SYN', '@130.8MHz:', 'DONE!']
# ['SYN', '@131.1MHz:', 'DONE!']
# ['SYN', '@131.4MHz:', 'DONE!']
# ['SYN', '@131.7MHz:', 'DONE!']
# ['SYN', '@132.0MHz:', 'DONE!']
# ['SYN', '@132.3MHz:', 'DONE!']
# ['SYN', '@132.6MHz:', 'DONE!']
# ['SYN', '@132.9MHz:', 'DONE!']
# ['SYN', '@133.2MHz:', 'DONE!']
# ['SYN', '@133.5MHz:', 'DONE!']
# ['SYN', '@133.8MHz:', 'DONE!']
# ['SYN', '@134.1MHz:', 'DONE!']
# ['SYN', '@134.4MHz:', 'DONE!']
# ['SYN', '@134.7MHz:', 'DONE!']
# ['SYN', '@135.0MHz:', 'DONE!']
# ['SYN', '@135.3MHz:', 'DONE!']
# ['SYN', '@135.6MHz:', 'DONE!']
# ['SYN', '@135.9MHz:', 'DONE!']
# ['SYN', '@136.2MHz:', 'DONE!']
# ['SYN', '@136.5MHz:', 'DONE!']
# ['SYN', '@136.8MHz:', 'DONE!']
# ['SYN', '@137.1MHz:', 'DONE!']
# ['SYN', '@137.4MHz:', 'DONE!']
# ['SYN', '@137.7MHz:', 'DONE!']
# ['SYN', '@138.0MHz:', 'DONE!']
# ['SYN', '@138.3MHz:', 'DONE!']
# ['SYN', '@138.6MHz:', 'DONE!']
# ['SYN', '@138.9MHz:', 'DONE!']
# ['SYN', '@139.2MHz:', 'DONE!']
# ['SYN', '@139.5MHz:', 'DONE!']
# ['SYN', '@139.8MHz:', 'DONE!']
# ['SYN', '@140.1MHz:', 'DONE!']
# ['SYN', '@140.4MHz:', 'DONE!']
# ['SYN', '@140.7MHz:', 'DONE!']
# ['SYN', '@141.0MHz:', 'DONE!']
# ['SYN', '@141.3MHz:', 'DONE!']
# ['SYN', '@141.6MHz:', 'DONE!']
# ['SYN', '@141.9MHz:', 'DONE!']
# ['SYN', '@142.2MHz:', 'DONE!']
# ['SYN', '@142.5MHz:', 'DONE!']
# ['SYN', '@142.8MHz:', 'DONE!']
# ['SYN', '@143.1MHz:', 'DONE!']
# ['SYN', '@143.4MHz:', 'DONE!']
# ['SYN', '@143.7MHz:', 'DONE!']
# ['SYN', '@144.0MHz:', 'DONE!']
# ['SYN', '@144.3MHz:', 'DONE!']
# ['SYN', '@144.6MHz:', 'DONE!']
# ['SYN', '@144.9MHz:', 'DONE!']
# ['SYN', '@145.2MHz:', 'DONE!']
# ['SYN', '@145.5MHz:', 'DONE!']
# ['SYN', '@145.8MHz:', 'DONE!']
# ['SYN', '@146.1MHz:', 'DONE!']
# ['SYN', '@146.4MHz:', 'DONE!']
# ['SYN', '@146.7MHz:', 'DONE!']
# ['SYN', '@147.0MHz:', 'DONE!']
# ['SYN', '@147.3MHz:', 'DONE!']
# ['SYN', '@147.6MHz:', 'DONE!']
# ['SYN', '@147.9MHz:', 'DONE!']
# ['SYN', '@148.2MHz:', 'DONE!']
# ['SYN', '@148.5MHz:', 'DONE!']
# ['SYN', '@148.8MHz:', 'DONE!']
# ['SYN', '@149.1MHz:', 'DONE!']
# ['SYN', '@149.4MHz:', 'DONE!']
# ['SYN', '@149.7MHz:', 'DONE!']
# ['SYN', '@150.0MHz:', 'DONE!']
# ['SYN', '@150.3MHz:', 'DONE!']
# ['SYN', '@150.6MHz:', 'DONE!']
# ['SYN', '@150.9MHz:', 'DONE!']
# ['SYN', '@151.2MHz:', 'DONE!']
# ['SYN', '@151.5MHz:', 'DONE!']
# ['SYN', '@151.8MHz:', 'DONE!']
# ['SYN', '@152.1MHz:', 'DONE!']
# ['SYN', '@152.4MHz:', 'DONE!']
# ['SYN', '@152.7MHz:', 'DONE!']
# ['SYN', '@153.0MHz:', 'DONE!']
# ['SYN', '@153.3MHz:', 'DONE!']
# ['SYN', '@153.6MHz:', 'DONE!']
# ['SYN', '@153.9MHz:', 'DONE!']
# ['SYN', '@154.2MHz:', 'DONE!']
# ['SYN', '@154.5MHz:', 'DONE!']
# ['SYN', '@154.8MHz:', 'DONE!']
# ['SYN', '@155.1MHz:', 'DONE!']
# ['SYN', '@155.4MHz:', 'DONE!']
# ['SYN', '@155.7MHz:', 'DONE!']
# ['SYN', '@156.0MHz:', 'DONE!']
# ['SYN', '@156.3MHz:', 'DONE!']
# ['SYN', '@156.6MHz:', 'DONE!']
# ['SYN', '@156.9MHz:', 'DONE!']
# ['SYN', '@157.2MHz:', 'DONE!']
# ['SYN', '@157.5MHz:', 'DONE!']
# ['SYN', '@157.8MHz:', 'DONE!']
# ['SYN', '@158.1MHz:', 'DONE!']
# ['SYN', '@158.4MHz:', 'DONE!']
# ['SYN', '@158.7MHz:', 'DONE!']
# ['SYN', '@159.0MHz:', 'DONE!']
# ['SYN', '@159.3MHz:', 'DONE!']
# ['SYN', '@159.6MHz:', 'DONE!']
# ['SYN', '@159.9MHz:', 'DONE!']
# ['SYN', '@160.2MHz:', 'DONE!']
# ['SYN', '@160.5MHz:', 'DONE!']
# ['SYN', '@160.8MHz:', 'DONE!']
# ['SYN', '@161.1MHz:', 'DONE!']
# ['SYN', '@161.4MHz:', 'DONE!']
# ['SYN', '@161.7MHz:', 'DONE!']
# ['SYN', '@162.0MHz:', 'DONE!']
# ['SYN', '@162.3MHz:', 'DONE!']
# ['SYN', '@162.6MHz:', 'DONE!']
# ['SYN', '@162.9MHz:', 'DONE!']
# ['SYN', '@163.2MHz:', 'DONE!']
# ['SYN', '@163.5MHz:', 'DONE!']
# ['SYN', '@163.8MHz:', 'DONE!']
# ['SYN', '@164.1MHz:', 'DONE!']
# ['SYN', '@164.4MHz:', 'DONE!']
# ['SYN', '@164.7MHz:', 'DONE!']
# ['SYN', '@165.0MHz:', 'DONE!']
# ['SYN', '@165.3MHz:', 'DONE!']
# ['SYN', '@165.6MHz:', 'DONE!']
# ['SYN', '@165.9MHz:', 'DONE!']
# ['SYN', '@166.2MHz:', 'DONE!']
# ['SYN', '@166.5MHz:', 'DONE!']
# ['SYN', '@166.8MHz:', 'DONE!']
# ['SYN', '@167.1MHz:', 'DONE!']
# ['SYN', '@167.4MHz:', 'DONE!']
# ['SYN', '@167.7MHz:', 'DONE!']
# ['SYN', '@168.0MHz:', 'DONE!']
# ['SYN', '@168.3MHz:', 'DONE!']
# ['SYN', '@168.6MHz:', 'DONE!']
# ['SYN', '@168.9MHz:', 'DONE!']
# ['SYN', '@169.2MHz:', 'DONE!']
# ['SYN', '@169.5MHz:', 'DONE!']
# ['SYN', '@169.8MHz:', 'DONE!']
# ['SYN', '@170.1MHz:', 'DONE!']
# ['SYN', '@170.4MHz:', 'DONE!']
# ['SYN', '@170.7MHz:', 'DONE!']
# ['SYN', '@171.0MHz:', 'DONE!']
# ['SYN', '@171.3MHz:', 'DONE!']
# ['SYN', '@171.6MHz:', 'DONE!']
# ['SYN', '@171.9MHz:', 'DONE!']
# ['SYN', '@172.2MHz:', 'DONE!']
# ['SYN', '@172.5MHz:', 'DONE!']
# ['SYN', '@172.8MHz:', 'DONE!']
# ['SYN', '@173.1MHz:', 'DONE!']
# ['SYN', '@173.39999999999998MHz:', 'DONE!']
# ['SYN', '@173.7MHz:', 'DONE!']
# ['SYN', '@174.0MHz:', 'DONE!']
# ['SYN', '@174.3MHz:', 'DONE!']
# ['SYN', '@174.6MHz:', 'DONE!']
# ['SYN', '@174.89999999999998MHz:', 'DONE!']
# ['SYN', '@175.2MHz:', 'DONE!']
# ['SYN', '@175.5MHz:', 'DONE!']
# ['SYN', '@175.8MHz:', 'DONE!']
# ['SYN', '@176.1MHz:', 'DONE!']
# ['SYN', '@176.39999999999998MHz:', 'DONE!']
# ['SYN', '@176.7MHz:', 'DONE!']
# ['SYN', '@177.0MHz:', 'DONE!']
# ['SYN', '@177.3MHz:', 'DONE!']
# ['SYN', '@177.6MHz:', 'DONE!']
# ['SYN', '@177.89999999999998MHz:', 'DONE!']
# ['SYN', '@178.2MHz:', 'DONE!']
# ['SYN', '@178.5MHz:', 'DONE!']
# ['SYN', '@178.8MHz:', 'DONE!']
# ['SYN', '@179.1MHz:', 'DONE!']
# ['SYN', '@179.39999999999998MHz:', 'DONE!']
# ['SYN', '@179.7MHz:', 'DONE!']
# ['SYN', '@180.0MHz:', 'DONE!']
# ['SYN', '@180.3MHz:', 'DONE!']
# ['SYN', '@180.6MHz:', 'DONE!']
# ['SYN', '@180.89999999999998MHz:', 'DONE!']
# ['SYN', '@181.2MHz:', 'DONE!']
# ['SYN', '@181.5MHz:', 'DONE!']
# ['SYN', '@181.8MHz:', 'DONE!']
# ['SYN', '@182.1MHz:', 'DONE!']
# ['SYN', '@182.39999999999998MHz:', 'DONE!']
# ['SYN', '@182.7MHz:', 'DONE!']
# ['SYN', '@183.0MHz:', 'DONE!']
# ['SYN', '@183.3MHz:', 'DONE!']
# ['SYN', '@183.6MHz:', 'DONE!']
# ['SYN', '@183.89999999999998MHz:', 'DONE!']
# ['SYN', '@184.2MHz:', 'DONE!']
# ['SYN', '@184.5MHz:', 'DONE!']
# ['SYN', '@184.8MHz:', 'DONE!']
# ['SYN', '@185.1MHz:', 'DONE!']
# ['SYN', '@185.39999999999998MHz:', 'DONE!']
# ['SYN', '@185.7MHz:', 'DONE!']
# ['SYN', '@186.0MHz:', 'DONE!']
# ['SYN', '@186.3MHz:', 'DONE!']
# ['SYN', '@186.6MHz:', 'DONE!']
# ['SYN', '@186.89999999999998MHz:', 'DONE!']
# ['SYN', '@187.2MHz:', 'DONE!']
# ['SYN', '@187.5MHz:', 'DONE!']
# ['SYN', '@187.8MHz:', 'DONE!']
# ['SYN', '@188.1MHz:', 'DONE!']
# ['SYN', '@188.39999999999998MHz:', 'DONE!']
# ['SYN', '@188.7MHz:', 'DONE!']
# ['SYN', '@189.0MHz:', 'DONE!']
# ['SYN', '@189.3MHz:', 'DONE!']
# ['SYN', '@189.6MHz:', 'DONE!']
# ['SYN', '@189.89999999999998MHz:', 'DONE!']
# ['SYN', '@190.2MHz:', 'DONE!']
# ['SYN', '@190.5MHz:', 'DONE!']
# ['SYN', '@190.8MHz:', 'DONE!']
# ['SYN', '@191.1MHz:', 'DONE!']
# ['SYN', '@191.39999999999998MHz:', 'DONE!']
# ['SYN', '@191.7MHz:', 'DONE!']
# ['SYN', '@192.0MHz:', 'DONE!']
# ['SYN', '@192.3MHz:', 'DONE!']
# ['SYN', '@192.6MHz:', 'DONE!']
# ['SYN', '@192.89999999999998MHz:', 'DONE!']
# ['SYN', '@193.2MHz:', 'DONE!']
# ['SYN', '@193.5MHz:', 'DONE!']
# ['SYN', '@193.8MHz:', 'DONE!']
# ['SYN', '@194.1MHz:', 'DONE!']
# ['SYN', '@194.39999999999998MHz:', 'DONE!']
# ['SYN', '@194.7MHz:', 'DONE!']
# ['SYN', '@195.0MHz:', 'DONE!']
# ['SYN', '@195.3MHz:', 'DONE!']
# ['SYN', '@195.6MHz:', 'DONE!']
# ['SYN', '@195.89999999999998MHz:', 'DONE!']
# ['SYN', '@196.2MHz:', 'DONE!']
# ['SYN', '@196.5MHz:', 'DONE!']
# ['SYN', '@196.8MHz:', 'DONE!']
# ['SYN', '@197.1MHz:', 'DONE!']
# ['SYN', '@197.39999999999998MHz:', 'DONE!']
# ['SYN', '@197.7MHz:', 'DONE!']
# ['SYN', '@198.0MHz:', 'DONE!']
# ['SYN', '@198.3MHz:', 'DONE!']
# ['SYN', '@198.6MHz:', 'DONE!']
# ['SYN', '@198.89999999999998MHz:', 'DONE!']
# ['SYN', '@199.2MHz:', 'DONE!']
# ['SYN', '@199.5MHz:', 'DONE!']
# ['SYN', '@199.8MHz:', 'DONE!']
# ['SYN', '@200.1MHz:', 'DONE!']
# ['SYN', '@200.39999999999998MHz:', 'DONE!']
# ['SYN', '@200.7MHz:', 'DONE!']
# ['SYN', '@201.0MHz:', 'DONE!']
# ['SYN', '@201.3MHz:', 'DONE!']
# ['SYN', '@201.6MHz:', 'DONE!']
# ['SYN', '@201.89999999999998MHz:', 'DONE!']
# ['SYN', '@202.2MHz:', 'DONE!']
# ['SYN', '@202.5MHz:', 'DONE!']
# ['SYN', '@202.8MHz:', 'DONE!']
# ['SYN', '@203.1MHz:', 'DONE!']
# ['SYN', '@203.39999999999998MHz:', 'DONE!']
# ['SYN', '@203.7MHz:', 'DONE!']
# ['SYN', '@204.0MHz:', 'DONE!']
# ['SYN', '@204.3MHz:', 'DONE!']
# ['SYN', '@204.6MHz:', 'DONE!']
# ['SYN', '@204.89999999999998MHz:', 'DONE!']
# ['SYN', '@205.2MHz:', 'DONE!']
# ['SYN', '@205.5MHz:', 'DONE!']
# ['SYN', '@205.8MHz:', 'DONE!']
# ['SYN', '@206.1MHz:', 'DONE!']
# ['SYN', '@206.39999999999998MHz:', 'DONE!']
# ['SYN', '@206.7MHz:', 'DONE!']
# ['SYN', '@207.0MHz:', 'DONE!']
# ['SYN', '@207.3MHz:', 'DONE!']
# ['SYN', '@207.6MHz:', 'DONE!']
# ['SYN', '@207.89999999999998MHz:', 'DONE!']
# ['SYN', '@208.2MHz:', 'DONE!']
# ['SYN', '@208.5MHz:', 'DONE!']
# ['SYN', '@208.8MHz:', 'DONE!']
# ['SYN', '@209.1MHz:', 'DONE!']
# ['SYN', '@209.39999999999998MHz:', 'DONE!']
# ['SYN', '@209.7MHz:', 'DONE!']
# ['SYN', '@210.0MHz:', 'DONE!']
# ['SYN', '@210.3MHz:', 'DONE!']
# CPU times: user 14 s, sys: 206 ms, total: 14.2 s
# Wall time: 14.2 s

# %%
plt.imshow(syn_test[:,:,0])
print(np.mean(syn_test[:,:,0]))
# Out:
# -0.02485291304144327

# %%
# %%time
ff_test = sim_test.gen_freefree_map() #free free emission, already meaned zero
hdu = fits.PrimaryHDU(ff_test)
hdul = fits.HDUList([hdu])
hdul.writeto('fits_files/ff_test.fits',overwrite=True)
# Out:
# Generating random field
# Generating random field
# ['FF', '@108.0MHz:', 'DONE!']
# ['FF', '@108.3MHz:', 'DONE!']
# ['FF', '@108.6MHz:', 'DONE!']
# ['FF', '@108.9MHz:', 'DONE!']
# ['FF', '@109.2MHz:', 'DONE!']
# ['FF', '@109.5MHz:', 'DONE!']
# ['FF', '@109.8MHz:', 'DONE!']
# ['FF', '@110.1MHz:', 'DONE!']
# ['FF', '@110.4MHz:', 'DONE!']
# ['FF', '@110.7MHz:', 'DONE!']
# ['FF', '@111.0MHz:', 'DONE!']
# ['FF', '@111.3MHz:', 'DONE!']
# ['FF', '@111.6MHz:', 'DONE!']
# ['FF', '@111.9MHz:', 'DONE!']
# ['FF', '@112.2MHz:', 'DONE!']
# ['FF', '@112.5MHz:', 'DONE!']
# ['FF', '@112.8MHz:', 'DONE!']
# ['FF', '@113.1MHz:', 'DONE!']
# ['FF', '@113.4MHz:', 'DONE!']
# ['FF', '@113.7MHz:', 'DONE!']
# ['FF', '@114.0MHz:', 'DONE!']
# ['FF', '@114.3MHz:', 'DONE!']
# ['FF', '@114.6MHz:', 'DONE!']
# ['FF', '@114.9MHz:', 'DONE!']
# ['FF', '@115.2MHz:', 'DONE!']
# ['FF', '@115.5MHz:', 'DONE!']
# ['FF', '@115.8MHz:', 'DONE!']
# ['FF', '@116.1MHz:', 'DONE!']
# ['FF', '@116.4MHz:', 'DONE!']
# ['FF', '@116.7MHz:', 'DONE!']
# ['FF', '@117.0MHz:', 'DONE!']
# ['FF', '@117.3MHz:', 'DONE!']
# ['FF', '@117.6MHz:', 'DONE!']
# ['FF', '@117.9MHz:', 'DONE!']
# ['FF', '@118.2MHz:', 'DONE!']
# ['FF', '@118.5MHz:', 'DONE!']
# ['FF', '@118.8MHz:', 'DONE!']
# ['FF', '@119.1MHz:', 'DONE!']
# ['FF', '@119.4MHz:', 'DONE!']
# ['FF', '@119.7MHz:', 'DONE!']
# ['FF', '@120.0MHz:', 'DONE!']
# ['FF', '@120.3MHz:', 'DONE!']
# ['FF', '@120.6MHz:', 'DONE!']
# ['FF', '@120.9MHz:', 'DONE!']
# ['FF', '@121.2MHz:', 'DONE!']
# ['FF', '@121.5MHz:', 'DONE!']
# ['FF', '@121.8MHz:', 'DONE!']
# ['FF', '@122.1MHz:', 'DONE!']
# ['FF', '@122.4MHz:', 'DONE!']
# ['FF', '@122.7MHz:', 'DONE!']
# ['FF', '@123.0MHz:', 'DONE!']
# ['FF', '@123.3MHz:', 'DONE!']
# ['FF', '@123.6MHz:', 'DONE!']
# ['FF', '@123.9MHz:', 'DONE!']
# ['FF', '@124.2MHz:', 'DONE!']
# ['FF', '@124.5MHz:', 'DONE!']
# ['FF', '@124.8MHz:', 'DONE!']
# ['FF', '@125.1MHz:', 'DONE!']
# ['FF', '@125.4MHz:', 'DONE!']
# ['FF', '@125.7MHz:', 'DONE!']
# ['FF', '@126.0MHz:', 'DONE!']
# ['FF', '@126.3MHz:', 'DONE!']
# ['FF', '@126.6MHz:', 'DONE!']
# ['FF', '@126.9MHz:', 'DONE!']
# ['FF', '@127.2MHz:', 'DONE!']
# ['FF', '@127.5MHz:', 'DONE!']
# ['FF', '@127.8MHz:', 'DONE!']
# ['FF', '@128.1MHz:', 'DONE!']
# ['FF', '@128.4MHz:', 'DONE!']
# ['FF', '@128.7MHz:', 'DONE!']
# ['FF', '@129.0MHz:', 'DONE!']
# ['FF', '@129.3MHz:', 'DONE!']
# ['FF', '@129.6MHz:', 'DONE!']
# ['FF', '@129.9MHz:', 'DONE!']
# ['FF', '@130.2MHz:', 'DONE!']
# ['FF', '@130.5MHz:', 'DONE!']
# ['FF', '@130.8MHz:', 'DONE!']
# ['FF', '@131.1MHz:', 'DONE!']
# ['FF', '@131.4MHz:', 'DONE!']
# ['FF', '@131.7MHz:', 'DONE!']
# ['FF', '@132.0MHz:', 'DONE!']
# ['FF', '@132.3MHz:', 'DONE!']
# ['FF', '@132.6MHz:', 'DONE!']
# ['FF', '@132.9MHz:', 'DONE!']
# ['FF', '@133.2MHz:', 'DONE!']
# ['FF', '@133.5MHz:', 'DONE!']
# ['FF', '@133.8MHz:', 'DONE!']
# ['FF', '@134.1MHz:', 'DONE!']
# ['FF', '@134.4MHz:', 'DONE!']
# ['FF', '@134.7MHz:', 'DONE!']
# ['FF', '@135.0MHz:', 'DONE!']
# ['FF', '@135.3MHz:', 'DONE!']
# ['FF', '@135.6MHz:', 'DONE!']
# ['FF', '@135.9MHz:', 'DONE!']
# ['FF', '@136.2MHz:', 'DONE!']
# ['FF', '@136.5MHz:', 'DONE!']
# ['FF', '@136.8MHz:', 'DONE!']
# ['FF', '@137.1MHz:', 'DONE!']
# ['FF', '@137.4MHz:', 'DONE!']
# ['FF', '@137.7MHz:', 'DONE!']
# ['FF', '@138.0MHz:', 'DONE!']
# ['FF', '@138.3MHz:', 'DONE!']
# ['FF', '@138.6MHz:', 'DONE!']
# ['FF', '@138.9MHz:', 'DONE!']
# ['FF', '@139.2MHz:', 'DONE!']
# ['FF', '@139.5MHz:', 'DONE!']
# ['FF', '@139.8MHz:', 'DONE!']
# ['FF', '@140.1MHz:', 'DONE!']
# ['FF', '@140.4MHz:', 'DONE!']
# ['FF', '@140.7MHz:', 'DONE!']
# ['FF', '@141.0MHz:', 'DONE!']
# ['FF', '@141.3MHz:', 'DONE!']
# ['FF', '@141.6MHz:', 'DONE!']
# ['FF', '@141.9MHz:', 'DONE!']
# ['FF', '@142.2MHz:', 'DONE!']
# ['FF', '@142.5MHz:', 'DONE!']
# ['FF', '@142.8MHz:', 'DONE!']
# ['FF', '@143.1MHz:', 'DONE!']
# ['FF', '@143.4MHz:', 'DONE!']
# ['FF', '@143.7MHz:', 'DONE!']
# ['FF', '@144.0MHz:', 'DONE!']
# ['FF', '@144.3MHz:', 'DONE!']
# ['FF', '@144.6MHz:', 'DONE!']
# ['FF', '@144.9MHz:', 'DONE!']
# ['FF', '@145.2MHz:', 'DONE!']
# ['FF', '@145.5MHz:', 'DONE!']
# ['FF', '@145.8MHz:', 'DONE!']
# ['FF', '@146.1MHz:', 'DONE!']
# ['FF', '@146.4MHz:', 'DONE!']
# ['FF', '@146.7MHz:', 'DONE!']
# ['FF', '@147.0MHz:', 'DONE!']
# ['FF', '@147.3MHz:', 'DONE!']
# ['FF', '@147.6MHz:', 'DONE!']
# ['FF', '@147.9MHz:', 'DONE!']
# ['FF', '@148.2MHz:', 'DONE!']
# ['FF', '@148.5MHz:', 'DONE!']
# ['FF', '@148.8MHz:', 'DONE!']
# ['FF', '@149.1MHz:', 'DONE!']
# ['FF', '@149.4MHz:', 'DONE!']
# ['FF', '@149.7MHz:', 'DONE!']
# ['FF', '@150.0MHz:', 'DONE!']
# ['FF', '@150.3MHz:', 'DONE!']
# ['FF', '@150.6MHz:', 'DONE!']
# ['FF', '@150.9MHz:', 'DONE!']
# ['FF', '@151.2MHz:', 'DONE!']
# ['FF', '@151.5MHz:', 'DONE!']
# ['FF', '@151.8MHz:', 'DONE!']
# ['FF', '@152.1MHz:', 'DONE!']
# ['FF', '@152.4MHz:', 'DONE!']
# ['FF', '@152.7MHz:', 'DONE!']
# ['FF', '@153.0MHz:', 'DONE!']
# ['FF', '@153.3MHz:', 'DONE!']
# ['FF', '@153.6MHz:', 'DONE!']
# ['FF', '@153.9MHz:', 'DONE!']
# ['FF', '@154.2MHz:', 'DONE!']
# ['FF', '@154.5MHz:', 'DONE!']
# ['FF', '@154.8MHz:', 'DONE!']
# ['FF', '@155.1MHz:', 'DONE!']
# ['FF', '@155.4MHz:', 'DONE!']
# ['FF', '@155.7MHz:', 'DONE!']
# ['FF', '@156.0MHz:', 'DONE!']
# ['FF', '@156.3MHz:', 'DONE!']
# ['FF', '@156.6MHz:', 'DONE!']
# ['FF', '@156.9MHz:', 'DONE!']
# ['FF', '@157.2MHz:', 'DONE!']
# ['FF', '@157.5MHz:', 'DONE!']
# ['FF', '@157.8MHz:', 'DONE!']
# ['FF', '@158.1MHz:', 'DONE!']
# ['FF', '@158.4MHz:', 'DONE!']
# ['FF', '@158.7MHz:', 'DONE!']
# ['FF', '@159.0MHz:', 'DONE!']
# ['FF', '@159.3MHz:', 'DONE!']
# ['FF', '@159.6MHz:', 'DONE!']
# ['FF', '@159.9MHz:', 'DONE!']
# ['FF', '@160.2MHz:', 'DONE!']
# ['FF', '@160.5MHz:', 'DONE!']
# ['FF', '@160.8MHz:', 'DONE!']
# ['FF', '@161.1MHz:', 'DONE!']
# ['FF', '@161.4MHz:', 'DONE!']
# ['FF', '@161.7MHz:', 'DONE!']
# ['FF', '@162.0MHz:', 'DONE!']
# ['FF', '@162.3MHz:', 'DONE!']
# ['FF', '@162.6MHz:', 'DONE!']
# ['FF', '@162.9MHz:', 'DONE!']
# ['FF', '@163.2MHz:', 'DONE!']
# ['FF', '@163.5MHz:', 'DONE!']
# ['FF', '@163.8MHz:', 'DONE!']
# ['FF', '@164.1MHz:', 'DONE!']
# ['FF', '@164.4MHz:', 'DONE!']
# ['FF', '@164.7MHz:', 'DONE!']
# ['FF', '@165.0MHz:', 'DONE!']
# ['FF', '@165.3MHz:', 'DONE!']
# ['FF', '@165.6MHz:', 'DONE!']
# ['FF', '@165.9MHz:', 'DONE!']
# ['FF', '@166.2MHz:', 'DONE!']
# ['FF', '@166.5MHz:', 'DONE!']
# ['FF', '@166.8MHz:', 'DONE!']
# ['FF', '@167.1MHz:', 'DONE!']
# ['FF', '@167.4MHz:', 'DONE!']
# ['FF', '@167.7MHz:', 'DONE!']
# ['FF', '@168.0MHz:', 'DONE!']
# ['FF', '@168.3MHz:', 'DONE!']
# ['FF', '@168.6MHz:', 'DONE!']
# ['FF', '@168.9MHz:', 'DONE!']
# ['FF', '@169.2MHz:', 'DONE!']
# ['FF', '@169.5MHz:', 'DONE!']
# ['FF', '@169.8MHz:', 'DONE!']
# ['FF', '@170.1MHz:', 'DONE!']
# ['FF', '@170.4MHz:', 'DONE!']
# ['FF', '@170.7MHz:', 'DONE!']
# ['FF', '@171.0MHz:', 'DONE!']
# ['FF', '@171.3MHz:', 'DONE!']
# ['FF', '@171.6MHz:', 'DONE!']
# ['FF', '@171.9MHz:', 'DONE!']
# ['FF', '@172.2MHz:', 'DONE!']
# ['FF', '@172.5MHz:', 'DONE!']
# ['FF', '@172.8MHz:', 'DONE!']
# ['FF', '@173.1MHz:', 'DONE!']
# ['FF', '@173.39999999999998MHz:', 'DONE!']
# ['FF', '@173.7MHz:', 'DONE!']
# ['FF', '@174.0MHz:', 'DONE!']
# ['FF', '@174.3MHz:', 'DONE!']
# ['FF', '@174.6MHz:', 'DONE!']
# ['FF', '@174.89999999999998MHz:', 'DONE!']
# ['FF', '@175.2MHz:', 'DONE!']
# ['FF', '@175.5MHz:', 'DONE!']
# ['FF', '@175.8MHz:', 'DONE!']
# ['FF', '@176.1MHz:', 'DONE!']
# ['FF', '@176.39999999999998MHz:', 'DONE!']
# ['FF', '@176.7MHz:', 'DONE!']
# ['FF', '@177.0MHz:', 'DONE!']
# ['FF', '@177.3MHz:', 'DONE!']
# ['FF', '@177.6MHz:', 'DONE!']
# ['FF', '@177.89999999999998MHz:', 'DONE!']
# ['FF', '@178.2MHz:', 'DONE!']
# ['FF', '@178.5MHz:', 'DONE!']
# ['FF', '@178.8MHz:', 'DONE!']
# ['FF', '@179.1MHz:', 'DONE!']
# ['FF', '@179.39999999999998MHz:', 'DONE!']
# ['FF', '@179.7MHz:', 'DONE!']
# ['FF', '@180.0MHz:', 'DONE!']
# ['FF', '@180.3MHz:', 'DONE!']
# ['FF', '@180.6MHz:', 'DONE!']
# ['FF', '@180.89999999999998MHz:', 'DONE!']
# ['FF', '@181.2MHz:', 'DONE!']
# ['FF', '@181.5MHz:', 'DONE!']
# ['FF', '@181.8MHz:', 'DONE!']
# ['FF', '@182.1MHz:', 'DONE!']
# ['FF', '@182.39999999999998MHz:', 'DONE!']
# ['FF', '@182.7MHz:', 'DONE!']
# ['FF', '@183.0MHz:', 'DONE!']
# ['FF', '@183.3MHz:', 'DONE!']
# ['FF', '@183.6MHz:', 'DONE!']
# ['FF', '@183.89999999999998MHz:', 'DONE!']
# ['FF', '@184.2MHz:', 'DONE!']
# ['FF', '@184.5MHz:', 'DONE!']
# ['FF', '@184.8MHz:', 'DONE!']
# ['FF', '@185.1MHz:', 'DONE!']
# ['FF', '@185.39999999999998MHz:', 'DONE!']
# ['FF', '@185.7MHz:', 'DONE!']
# ['FF', '@186.0MHz:', 'DONE!']
# ['FF', '@186.3MHz:', 'DONE!']
# ['FF', '@186.6MHz:', 'DONE!']
# ['FF', '@186.89999999999998MHz:', 'DONE!']
# ['FF', '@187.2MHz:', 'DONE!']
# ['FF', '@187.5MHz:', 'DONE!']
# ['FF', '@187.8MHz:', 'DONE!']
# ['FF', '@188.1MHz:', 'DONE!']
# ['FF', '@188.39999999999998MHz:', 'DONE!']
# ['FF', '@188.7MHz:', 'DONE!']
# ['FF', '@189.0MHz:', 'DONE!']
# ['FF', '@189.3MHz:', 'DONE!']
# ['FF', '@189.6MHz:', 'DONE!']
# ['FF', '@189.89999999999998MHz:', 'DONE!']
# ['FF', '@190.2MHz:', 'DONE!']
# ['FF', '@190.5MHz:', 'DONE!']
# ['FF', '@190.8MHz:', 'DONE!']
# ['FF', '@191.1MHz:', 'DONE!']
# ['FF', '@191.39999999999998MHz:', 'DONE!']
# ['FF', '@191.7MHz:', 'DONE!']
# ['FF', '@192.0MHz:', 'DONE!']
# ['FF', '@192.3MHz:', 'DONE!']
# ['FF', '@192.6MHz:', 'DONE!']
# ['FF', '@192.89999999999998MHz:', 'DONE!']
# ['FF', '@193.2MHz:', 'DONE!']
# ['FF', '@193.5MHz:', 'DONE!']
# ['FF', '@193.8MHz:', 'DONE!']
# ['FF', '@194.1MHz:', 'DONE!']
# ['FF', '@194.39999999999998MHz:', 'DONE!']
# ['FF', '@194.7MHz:', 'DONE!']
# ['FF', '@195.0MHz:', 'DONE!']
# ['FF', '@195.3MHz:', 'DONE!']
# ['FF', '@195.6MHz:', 'DONE!']
# ['FF', '@195.89999999999998MHz:', 'DONE!']
# ['FF', '@196.2MHz:', 'DONE!']
# ['FF', '@196.5MHz:', 'DONE!']
# ['FF', '@196.8MHz:', 'DONE!']
# ['FF', '@197.1MHz:', 'DONE!']
# ['FF', '@197.39999999999998MHz:', 'DONE!']
# ['FF', '@197.7MHz:', 'DONE!']
# ['FF', '@198.0MHz:', 'DONE!']
# ['FF', '@198.3MHz:', 'DONE!']
# ['FF', '@198.6MHz:', 'DONE!']
# ['FF', '@198.89999999999998MHz:', 'DONE!']
# ['FF', '@199.2MHz:', 'DONE!']
# ['FF', '@199.5MHz:', 'DONE!']
# ['FF', '@199.8MHz:', 'DONE!']
# ['FF', '@200.1MHz:', 'DONE!']
# ['FF', '@200.39999999999998MHz:', 'DONE!']
# ['FF', '@200.7MHz:', 'DONE!']
# ['FF', '@201.0MHz:', 'DONE!']
# ['FF', '@201.3MHz:', 'DONE!']
# ['FF', '@201.6MHz:', 'DONE!']
# ['FF', '@201.89999999999998MHz:', 'DONE!']
# ['FF', '@202.2MHz:', 'DONE!']
# ['FF', '@202.5MHz:', 'DONE!']
# ['FF', '@202.8MHz:', 'DONE!']
# ['FF', '@203.1MHz:', 'DONE!']
# ['FF', '@203.39999999999998MHz:', 'DONE!']
# ['FF', '@203.7MHz:', 'DONE!']
# ['FF', '@204.0MHz:', 'DONE!']
# ['FF', '@204.3MHz:', 'DONE!']
# ['FF', '@204.6MHz:', 'DONE!']
# ['FF', '@204.89999999999998MHz:', 'DONE!']
# ['FF', '@205.2MHz:', 'DONE!']
# ['FF', '@205.5MHz:', 'DONE!']
# ['FF', '@205.8MHz:', 'DONE!']
# ['FF', '@206.1MHz:', 'DONE!']
# ['FF', '@206.39999999999998MHz:', 'DONE!']
# ['FF', '@206.7MHz:', 'DONE!']
# ['FF', '@207.0MHz:', 'DONE!']
# ['FF', '@207.3MHz:', 'DONE!']
# ['FF', '@207.6MHz:', 'DONE!']
# ['FF', '@207.89999999999998MHz:', 'DONE!']
# ['FF', '@208.2MHz:', 'DONE!']
# ['FF', '@208.5MHz:', 'DONE!']
# ['FF', '@208.8MHz:', 'DONE!']
# ['FF', '@209.1MHz:', 'DONE!']
# ['FF', '@209.39999999999998MHz:', 'DONE!']
# ['FF', '@209.7MHz:', 'DONE!']
# ['FF', '@210.0MHz:', 'DONE!']
# ['FF', '@210.3MHz:', 'DONE!']
# CPU times: user 14 s, sys: 182 ms, total: 14.1 s
# Wall time: 14.1 s

# %%
plt.imshow(ff_test[:,:,0])
print(np.mean(ff_test[:,:,0]))
# Out:
# 5.5760317869746334e-05

# %%
# %%time
egfg_test = sim_test.gen_exgal_map() #extra galatic, needs normalising
# Out:
# CPU times: user 22min 5s, sys: 32min 13s, total: 54min 19s
# Wall time: 1h 16min 11s

# %%
plt.imshow(egfg_test[:,:,30])
print(np.mean(egfg_test[:,:,30])) # needs to be meaned zero
# Out:
# 78.27391961676513

# %%
new_egfg = np.zeros(np.shape(egfg_test))
#normalise and centre at zero
for i in range(steps):
    x = np.mean(egfg_test[:,:,i])
    new_egfg[:,:,i] = (egfg_test[:,:,i]) - x
print(np.mean(new_egfg[:,:,30]))
# Out:
# -8.756884106730922e-15

# %%
hdu = fits.PrimaryHDU(new_egfg)
hdul = fits.HDUList([hdu])
hdul.writeto('fits_files/new_egfg_test.fits',overwrite=True)

# %%
noise = fits.getdata(r'fits_files/noise_108.000MHz_210.300MHz_' \
                     r'SKA_SKA_central_area_EOR0_0128_3.0_1000h_K.fits').T

plt.imshow(noise[:,:,0])

# %%
foregrounds_noise = syn_test + ff_test + new_egfg + noise  #noise break down signal

fig = plt.figure(figsize=(10,10))

ax = fig.add_subplot(2,2,1)
im0 = ax.imshow(syn_test[:,:,0])
ax.set_title('synchrotron emission')
fig.colorbar(im0,ax=ax)

ax = fig.add_subplot(2,2,2)
im0 = ax.imshow(ff_test[:,:,0])
ax.set_title('free free emission')
fig.colorbar(im0,ax=ax)

ax = fig.add_subplot(2,2,3)
im0 = ax.imshow(new_egfg[:,:,0])
ax.set_title('Extra-Galactic')
fig.colorbar(im0,ax=ax)

ax = fig.add_subplot(2,2,4)
im0 = ax.imshow(noise[:,:,0])
ax.set_title('Noise')
fig.colorbar(im0,ax=ax)
plt.tight_layout()
plt.show()

fig.savefig('images/All_Foreground and noise.png')

# %%
plt.imshow(foregrounds_noise[:,:,0])
plt.title('Combined Foregrounds and noise')
plt.colorbar()
plt.savefig('images/combined foregrounds and noise')

# %%
foregrounds =syn_test + ff_test + new_egfg
hdu = fits.PrimaryHDU(foregrounds)
hdul = fits.HDUList([hdu])
hdul.writeto('fits_files/fg_all.fits',overwrite=True)

# %% [markdown]
# ## plotting noise against frequencies

# %%
#load files
syn_test = fits.getdata('fits_files/syn_test.fits')
new_egfg = fits.getdata('fits_files/new_egfg_test.fits')
ff_test = fits.getdata('fits_files/ff_test.fits')
noise = fits.getdata(r'fits_files/noise_108.000MHz_210.300MHz_' \
                     r'SKA_SKA_central_area_EOR0_0128_3.0_1000h_K.fits').T

# %%
def RootMeanSquare(image):
    rms = np.sqrt(np.abs(np.mean(image)))
    return rms
def newtime(new_number):
    old_number = 1000
    time = np.sqrt(np.float(old_number)/(np.float(new_number)))
    return time


#change the number of hours the signal is measured
new_number = 10
Noise_100 = np.zeros((128,128,342))
rmsNoise_100 = np.zeros(342)
meanNoise_100 = np.zeros(342)
for i in range(342):
    noise_100 = noise[:,:,i]*newtime(new_number)
    rmsNoise_100[i] = RootMeanSquare(noise_100)
    meanNoise_100[i] = np.mean(noise_100)
    Noise_100[:,:,i] = noise_100[:,:]


rmsNoise_1000 = np.zeros(342)
meanNoise_1000 = np.zeros(342)
#rms of the 1000 hours noise
for i in range(342):
    rmsNoise_1000[i] = RootMeanSquare(noise[:,:,i])
    meanNoise_1000[i] = np.mean(noise[:,:,i])

new_number = 20000
Noise_10000 = np.zeros((128,128,342))
rmsNoise_10000 = np.zeros(342)
meanNoise_10000 = np.zeros(342)
for i in range(342):
    noise_10000 = noise[:,:,i]*newtime(new_number)
    rmsNoise_10000[i]  = RootMeanSquare(noise_10000)
    meanNoise_10000[i] = np.mean(noise_10000)
    Noise_10000[:,:,i] = noise_10000[:,:]
    
    
#plot figures    
x = np.linspace(108,208.3,342)
fig, ax = plt.subplots(1, 2,figsize=(10,4))

ax[0].plot(x,rmsNoise_100,'r-',label='100 hours')
ax[0].plot(x,rmsNoise_1000,'b-',label='1000 hours')
ax[0].plot(x,rmsNoise_10000,'g-',label='1000 hours')
ax[0].set_xlabel('Frequency (MHz)')
ax[0].set_ylabel('rms signal (k)')
ax[0].set_title('rms against frequency')
ax[0].legend()

ax[1].plot(x,meanNoise_100,'r-',label='100 hours')
ax[1].plot(x,meanNoise_1000,'b-',label='1000 hours')
ax[1].plot(x,meanNoise_10000,'g-',label='10000 hours')
ax[1].set_xlabel('Frequency (MHz)')
ax[1].set_ylabel('mean signal (k)')
ax[1].set_title('mean against frequency')
ax[1].legend()

plt.tight_layout()

plt.savefig('images/mean_and_rms.png')

#save different hours files
#hdu = fits.PrimaryHDU(Noise_10000)
#hdul = fits.HDUList([hdu])
#hdul.writeto('fits_files/Noise_10000.fits',overwrite=True)

#hdu = fits.PrimaryHDU(Noise_100)
#hdul = fits.HDUList([hdu])
#hdul.writeto('fits_files/Noise_100.fits',overwrite=True)
# Out:
# /var/folders/cn/hgkqq8gj3f1b1yfslflsqszc0000gr/T/ipykernel_51664/2433647052.py:6: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   time = np.sqrt(np.float(old_number)/(np.float(new_number)))

# %%
#load foregound separately
indata_cs = fits.getdata('boxes/test.fits').T
indata_cs = indata_cs/1000   #convert to mili kelvins
print(indata_cs.shape)
# Out:
# (128, 128, 342)

# %%
#load foregound separately
light = fits.getdata('boxes/test.fits').T
light = indata_cs/1000   #convert to mili kelvins




var_gal = np.zeros(342)
var_syn = np.zeros(342)
var_free = np.zeros(342)
var_noise = np.zeros(342)
var_light = np.zeros(342)
for i in range(342):
    var_syn[i] = np.var(syn_test[:,:,i])
    var_gal[i] = np.var(new_egfg[:,:,i])
    var_free[i] = np.var(ff_test[:,:,i])
    var_noise[i] = np.var(noise[:,:,i])
    var_light[i] = np.var(light[:,:,i])




x = np.linspace(108,208.3,342)
fig = plt.figure(figsize=(10,10))

ax = fig.add_subplot(2,2,1)
ax.plot(x,var_gal,'r-',label = 'extra galatic')
ax.plot(x,var_syn,'b-', label = 'syncrotron emission')
ax.plot(x,var_free,'g-', label='free free emission')
ax.plot(x, var_noise,'tab:purple', label = 'noise')
ax.plot(x, var_light, 'c-', label = '21cm signal')
ax.set_xlabel('frequency (MHZ)')
ax.set_ylabel('variance (K)')
ax.set_title('variance against frequency')
ax.legend()

ax = fig.add_subplot(2,2,2)
ax.plot(x,var_free,'g-', label='free free emission')
ax.set_xlabel('frequency (MHZ)')
ax.set_ylabel('variance (K)')
ax.set_title('variance against frequency')
ax.legend()

ax = fig.add_subplot(2,2,3)
ax.plot(x, var_noise,'tab:purple', label = 'noise')
ax.set_xlabel('frequency (MHZ)')
ax.set_ylabel('variance (K)')
ax.set_title('variance against frequency')
ax.legend()

ax = fig.add_subplot(2,2,4)
ax.plot(x, var_light, 'c-', label = '21cm signal')
ax.set_xlabel('frequency (MHZ)')
ax.set_ylabel('variance (K)')
ax.set_title('variance against frequency')
ax.legend()

plt.tight_layout()

plt.savefig('images/variance_against_frequency.png')
